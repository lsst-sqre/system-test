# %% [markdown]
# ## Tracking EFD timestamp offsets

# %% [markdown]
# In this notebook we analyse the timestamps currenlty stored in the EFD.

# %%
import aioinflux
import getpass
import numpy as np

# %% [markdown]
# We'll access the EFD instance deployed at the Summit that is being used since September 7 for the AuxTel activities. You need to be at NOAO network to run this.

# %%
username = "saluser"
password = getpass.getpass(f"Password for {username}:")
# Out:
# Password for saluser:········

# %% [markdown]
# The following configures the `aioinflux` Python client to connect to the DM-EFD InfluxDB instance.

# %%
client = aioinflux.InfluxDBClient(host='summit-influxdb-efd.lsst.codes', 
                                  port='443', 
                                  ssl=True, 
                                  username=username, 
                                  password=password,
                                  db='efd')

# %% [markdown]
# We can configure the output to be a Pandas dataframe.

# %%
client.output = 'dataframe'

# %% [markdown]
# ## Listing topics
# Topics are mapped to [InfluxDB measurements](https://docs.influxdata.com/influxdb/v1.7/concepts/key_concepts/#measurement). The following query simply lists all topics in the InfluxDB `efd` database:

# %%
topics = await client.query('SHOW MEASUREMENTS')

# %% [markdown]
# ## Timestamp offsets
# We'll loop over all topics and compute the difference between `private_rcvStamp` and `private_sndStamp`

# %%
for topic in topics.values:
    topic_name = topic[0]
    tmp = await client.query(f'SELECT "private_rcvStamp" -"private_sndStamp"  FROM "efd"."autogen"."{topic_name}"')
    offsets = [value[0] for value in tmp.values]
    print(topic_name, np.mean(offsets))
# Out:
# lsst.sal.ATAOS.ackcmd 6.373249221004937
# lsst.sal.ATAOS.command_disable 0.0005314946174621582
# lsst.sal.ATAOS.command_disableCorrection 0.0005851813725062779
# lsst.sal.ATAOS.command_enable 0.0017339672361101424
# lsst.sal.ATAOS.command_enableCorrection 0.0006350370553823618
# lsst.sal.ATAOS.command_exitControl 0.0004227161407470703
# lsst.sal.ATAOS.command_setLogLevel 0.0005919933319091797
# lsst.sal.ATAOS.command_standby 0.00048535210745675225
# lsst.sal.ATAOS.command_start 0.0005465535556568819
# lsst.sal.ATAOS.logevent_appliedSettingsMatchStart 4.626173630356789
# lsst.sal.ATAOS.logevent_correctionEnabled 0.0003806432088216146
# lsst.sal.ATAOS.logevent_detailedState 0.0005154931526718021
# lsst.sal.ATAOS.logevent_errorCode 0.0003252983093261719
# lsst.sal.ATAOS.logevent_heartbeat 0.559361488913188
# lsst.sal.ATAOS.logevent_logLevel 7.6897307350521995
# lsst.sal.ATAOS.logevent_logMessage 0.009350216976795717
# lsst.sal.ATAOS.logevent_m1CorrectionCompleted 0.00032014807040607975
# lsst.sal.ATAOS.logevent_m1CorrectionStarted 0.00033362833239755293
# lsst.sal.ATAOS.logevent_settingVersions 5.347365140914917
# lsst.sal.ATAOS.logevent_simulationMode 11.525235652923584
# lsst.sal.ATAOS.logevent_summaryState 5.070811929987438
# lsst.sal.ATDome.ackcmd 0.00016327699025472006
# lsst.sal.ATDome.command_enable 0.000522613525390625
# lsst.sal.ATDome.command_homeAzimuth 0.0005958080291748047
# lsst.sal.ATDome.command_moveAzimuth 0.0003969920308966386
# lsst.sal.ATDome.command_standby 0.0006406307220458984
# lsst.sal.ATDome.command_start 0.0005643367767333984
# lsst.sal.ATDome.command_stopMotion 0.0005335807800292969
# lsst.sal.ATDome.logevent_allAxesInPosition 0.00021386146545410156
# lsst.sal.ATDome.logevent_appliedSettingsMatchStart 0.000225067138671875
# lsst.sal.ATDome.logevent_azimuthCommandedState 0.00017713245592619243
# lsst.sal.ATDome.logevent_azimuthInPosition 0.00019249916076660156
# lsst.sal.ATDome.logevent_azimuthState 0.00023093976472553454
# lsst.sal.ATDome.logevent_dropoutDoorCommandedState 410.8431078195572
# lsst.sal.ATDome.logevent_dropoutDoorState 0.00022649765014648438
# lsst.sal.ATDome.logevent_emergencyStop 0.0002732276916503906
# lsst.sal.ATDome.logevent_errorCode 0.0002627372741699219
# lsst.sal.ATDome.logevent_heartbeat 0.00043931814467145164
# lsst.sal.ATDome.logevent_logLevel 821.7019917964935
# lsst.sal.ATDome.logevent_logMessage 273.90075159072876
# lsst.sal.ATDome.logevent_mainDoorCommandedState 547.7900439898173
# lsst.sal.ATDome.logevent_mainDoorState 0.0002422332763671875
# lsst.sal.ATDome.logevent_scbLink 0.00018203258514404297
# lsst.sal.ATDome.logevent_settingVersions 410.8429116010666
# lsst.sal.ATDome.logevent_settingsAppliedDomeController 0.00020956993103027344
# lsst.sal.ATDome.logevent_settingsAppliedDomeTcp 0.0002633333206176758
# lsst.sal.ATDome.logevent_shutterInPosition 0.00020623207092285156
# lsst.sal.ATDome.logevent_simulationMode 821.7006487846375
# lsst.sal.ATDome.logevent_summaryState 117.38589882850647
# lsst.sal.ATDome.position 0.0002745246907502292
# lsst.sal.ATDomeTrajectory.ackcmd 0.000362228339826557
# lsst.sal.ATDomeTrajectory.command_disable 0.0006001989046732584
# lsst.sal.ATDomeTrajectory.command_enable 0.0005484177516056941
# lsst.sal.ATDomeTrajectory.command_standby 0.000506448745727539
# lsst.sal.ATDomeTrajectory.command_start 0.0008821704170920632
# lsst.sal.ATDomeTrajectory.logevent_appliedSettingsMatchStart 0.0004863088781183416
# lsst.sal.ATDomeTrajectory.logevent_heartbeat 0.017703666544726115
# lsst.sal.ATDomeTrajectory.logevent_logLevel 0.0029827753702799478
# lsst.sal.ATDomeTrajectory.logevent_logMessage 0.0004975252774154807
# lsst.sal.ATDomeTrajectory.logevent_settingVersions 0.0005559004270113432
# lsst.sal.ATDomeTrajectory.logevent_settingsApplied 0.0002956390380859375
# lsst.sal.ATDomeTrajectory.logevent_simulationMode 0.00300447146097819
# lsst.sal.ATDomeTrajectory.logevent_summaryState 0.0004749000072479248
# lsst.sal.ATHexapod.ackcmd 37.00078420375816
# lsst.sal.ATHexapod.command_disable 0.031179257801600864
# lsst.sal.ATHexapod.command_enable 0.004071201596941266
# lsst.sal.ATHexapod.command_moveToPosition 0.0005816069860306997
# lsst.sal.ATHexapod.command_standby 0.007343769073486328
# lsst.sal.ATHexapod.command_start 0.0005518674850463867
# lsst.sal.ATHexapod.logevent_appliedSettingsMatchStart 37.00018358230591
# lsst.sal.ATHexapod.logevent_detailedState 37.00020376288373
# lsst.sal.ATHexapod.logevent_heartbeat 37.01451024897493
# lsst.sal.ATHexapod.logevent_inPosition 37.00023333948167
# lsst.sal.ATHexapod.logevent_logLevel 37.2000572681427
# lsst.sal.ATHexapod.logevent_logMessage 37.00098859296655
# lsst.sal.ATHexapod.logevent_positionUpdate 37.00023559161595
# lsst.sal.ATHexapod.logevent_settingVersions 37.191657304763794
# lsst.sal.ATHexapod.logevent_settingsAppliedPivot 37.00025241715567
# lsst.sal.ATHexapod.logevent_settingsAppliedPositionLimits 37.000216790608
# lsst.sal.ATHexapod.logevent_settingsAppliedTcp 37.00029880659921
# lsst.sal.ATHexapod.logevent_settingsAppliedVelocities 37.00020708356585
# lsst.sal.ATHexapod.logevent_simulationMode 37.188578844070435
# lsst.sal.ATHexapod.logevent_summaryState 37.009382321916775
# lsst.sal.ATHexapod.positionStatus 37.00180926734972
# lsst.sal.ATMCS.ackcmd 22.946847726409718
# lsst.sal.ATMCS.azEl_mountMotorEncoders 23.018943505623927
# lsst.sal.ATMCS.command_disable 0.000628619358457368
# lsst.sal.ATMCS.command_enable 0.0007918548583984375
# lsst.sal.ATMCS.command_enterControl 0.0005981922149658203
# lsst.sal.ATMCS.command_standby 0.0005876590956502886
# lsst.sal.ATMCS.command_start 0.0006731832531136526
# lsst.sal.ATMCS.command_startTracking 34.035211926625095
# lsst.sal.ATMCS.command_stopTracking 34.155513525009155
# lsst.sal.ATMCS.command_trackTarget 37.00853558678761
# lsst.sal.ATMCS.logevent_allAxesInPosition 92.66571779176898
# lsst.sal.ATMCS.logevent_appliedSettingsMatchStart 2162.009581378102
# lsst.sal.ATMCS.logevent_atMountState 76.42759799190345
# lsst.sal.ATMCS.logevent_azimuthBrake1 1013.1288183386936
# lsst.sal.ATMCS.logevent_azimuthBrake2 22.828185721447593
# lsst.sal.ATMCS.logevent_azimuthDrive1Status 22.830579435616208
# lsst.sal.ATMCS.logevent_azimuthDrive2Status 22.831167968393068
# lsst.sal.ATMCS.logevent_azimuthInPosition 23.03140201539835
# lsst.sal.ATMCS.logevent_azimuthLimitSwitchCCW 22.76329559939248
# lsst.sal.ATMCS.logevent_azimuthLimitSwitchCW 22.595913849093698
# lsst.sal.ATMCS.logevent_azimuthToppleBlockCCW 22.819310442606607
# lsst.sal.ATMCS.logevent_azimuthToppleBlockCW 22.801878707749502
# lsst.sal.ATMCS.logevent_elevationBrake 22.79874941670751
# lsst.sal.ATMCS.logevent_elevationDriveStatus 22.798977451152112
# lsst.sal.ATMCS.logevent_elevationInPosition 22.93122500246437
# lsst.sal.ATMCS.logevent_elevationLimitSwitchLower 22.713211349078588
# lsst.sal.ATMCS.logevent_elevationLimitSwitchUpper 22.70267029106617
# lsst.sal.ATMCS.logevent_errorCode 126.9729135015206
# lsst.sal.ATMCS.logevent_heartbeat 22.72824379492334
# lsst.sal.ATMCS.logevent_m3DriveStatus 22.584443733096123
# lsst.sal.ATMCS.logevent_m3InPosition 22.681433268955775
# lsst.sal.ATMCS.logevent_m3RotatorDetentSwitches 22.48301551077101
# lsst.sal.ATMCS.logevent_m3RotatorLimitSwitchCCW 22.671294246401107
# lsst.sal.ATMCS.logevent_m3RotatorLimitSwitchCW 22.482450630929733
# lsst.sal.ATMCS.logevent_m3State 22.80110931763282
# lsst.sal.ATMCS.logevent_nasmyth1Brake 22.813221366255434
# lsst.sal.ATMCS.logevent_nasmyth1DriveStatus 22.8146601423517
# lsst.sal.ATMCS.logevent_nasmyth1LimitSwitchCCW 22.75193621431078
# lsst.sal.ATMCS.logevent_nasmyth1LimitSwitchCW 22.748883043016708
# lsst.sal.ATMCS.logevent_nasmyth1RotatorInPosition 22.95448924181845
# lsst.sal.ATMCS.logevent_nasmyth2Brake 22.751342448811073
# lsst.sal.ATMCS.logevent_nasmyth2DriveStatus 22.75063556331699
# lsst.sal.ATMCS.logevent_nasmyth2LimitSwitchCCW 22.732410890715464
# lsst.sal.ATMCS.logevent_nasmyth2LimitSwitchCW 22.721338561603
# lsst.sal.ATMCS.logevent_nasmyth2RotatorInPosition 23.29624205827713
# lsst.sal.ATMCS.logevent_settingVersions 22.857437209385196
# lsst.sal.ATMCS.logevent_summaryState 23.234335536251475
# lsst.sal.ATMCS.logevent_target 23.77573884126285
# lsst.sal.ATMCS.measuredMotorVelocity 23.019098858195587
# lsst.sal.ATMCS.measuredTorque 23.019715060802962
# lsst.sal.ATMCS.mount_AzEl_Encoders 23.020178421621104
# lsst.sal.ATMCS.mount_Nasmyth_Encoders 23.020656742919215
# lsst.sal.ATMCS.nasymth_m3_mountMotorEncoders 23.02042865283186
# lsst.sal.ATMCS.torqueDemand 23.022201977095605
# lsst.sal.ATMCS.trajectory 23.022276768006467
# lsst.sal.ATPneumatics.ackcmd 22.680688864955705
# lsst.sal.ATPneumatics.command_closeInstrumentAirValve 0.0007024407386779785
# lsst.sal.ATPneumatics.command_closeM1Cover 0.0006299813588460287
# lsst.sal.ATPneumatics.command_closeMasterAirSupply 0.000807779175894601
# lsst.sal.ATPneumatics.command_disable 0.0005330145359039307
# lsst.sal.ATPneumatics.command_enable 0.0007409519619411892
# lsst.sal.ATPneumatics.command_m1CloseAirValve 0.0005629658699035645
# lsst.sal.ATPneumatics.command_m1OpenAirValve 0.0008582745568226959
# lsst.sal.ATPneumatics.command_m1SetPressure 0.0025466361636023193
# lsst.sal.ATPneumatics.command_openInstrumentAirValve 0.0007480733534869025
# lsst.sal.ATPneumatics.command_openM1CellVents 0.0006940364837646484
# lsst.sal.ATPneumatics.command_openM1Cover 0.0005476176738739014
# lsst.sal.ATPneumatics.command_openMasterAirSupply 0.0006884130938299771
# lsst.sal.ATPneumatics.command_standby 3.6001620292663574
# lsst.sal.ATPneumatics.command_start 6.644137364167434
# lsst.sal.ATPneumatics.loadCell 23.59520706243691
# lsst.sal.ATPneumatics.logevent_appliedSettingsMatchStart 23.11157170464011
# lsst.sal.ATPneumatics.logevent_cellVentsState 23.011688546436588
# lsst.sal.ATPneumatics.logevent_eStop 22.639108625027017
# lsst.sal.ATPneumatics.logevent_errorCode 24.170512080192566
# lsst.sal.ATPneumatics.logevent_heartbeat 22.727164078868256
# lsst.sal.ATPneumatics.logevent_instrumentState 23.33805673463004
# lsst.sal.ATPneumatics.logevent_m1CoverLimitSwitches 22.938219218883873
# lsst.sal.ATPneumatics.logevent_m1CoverState 23.06229167755204
# lsst.sal.ATPneumatics.logevent_m1SetPressure 22.677910914236286
# lsst.sal.ATPneumatics.logevent_m1State 23.491083744095594
# lsst.sal.ATPneumatics.logevent_m1VentsLimitSwitches 22.5871076742808
# lsst.sal.ATPneumatics.logevent_m1VentsPosition 22.60883667945862
# lsst.sal.ATPneumatics.logevent_m2State 23.17231282922957
# lsst.sal.ATPneumatics.logevent_mainValveState 23.519052787260577
# lsst.sal.ATPneumatics.logevent_powerStatus 22.641413705689565
# lsst.sal.ATPneumatics.logevent_settingVersions 23.11179245219511
# lsst.sal.ATPneumatics.logevent_summaryState 23.172050813833874
# lsst.sal.ATPneumatics.m1AirPressure 23.617214023279757
# lsst.sal.ATPneumatics.m2AirPressure 23.57890355660381
# lsst.sal.ATPneumatics.mainAirSourcePressure 23.59797017481995
# lsst.sal.ATPtg.ackcmd 319.8263885268779
# lsst.sal.ATPtg.command_azElTarget 0.0010114941028279995
# lsst.sal.ATPtg.command_disable 2.849565166693467
# lsst.sal.ATPtg.command_enable 0.4810471828881796
# lsst.sal.ATPtg.command_exitControl 4.625612854957581
# lsst.sal.ATPtg.command_offsetAbsorb 0.0006016890207926432
# lsst.sal.ATPtg.command_offsetAzEl 0.0005201914673479497
# lsst.sal.ATPtg.command_offsetRADec 0.0004984885454177856
# lsst.sal.ATPtg.command_planetTarget 0.0006577968597412109
# lsst.sal.ATPtg.command_pointAddData 12.333750152587891
# lsst.sal.ATPtg.command_pointCloseFile 9.867106286684672
# lsst.sal.ATPtg.command_pointLoadModel 0.0005692981538318452
# lsst.sal.ATPtg.command_pointNewFile 10.000473763491657
# lsst.sal.ATPtg.command_raDecTarget 0.0005836370918485853
# lsst.sal.ATPtg.command_standby 0.4874543516259444
# lsst.sal.ATPtg.command_start 0.48418765753702403
# lsst.sal.ATPtg.command_startTracking 0.0007079442342122396
# lsst.sal.ATPtg.command_stopTracking 0.0006573638137505979
# lsst.sal.ATPtg.currentTargetStatus 37.00582645228026
# lsst.sal.ATPtg.currentTimesToLimits 37.147101918079095
# lsst.sal.ATPtg.guidingAndOffsets 37.005548851699025
# lsst.sal.ATPtg.logevent_airmassWarning 37.1219391922156
# lsst.sal.ATPtg.logevent_azWrapWarning 64522.890476786575
# lsst.sal.ATPtg.logevent_blindSpotWarning 64522.8905807889
# lsst.sal.ATPtg.logevent_currentDebugLevel 7711.305922299469
# lsst.sal.ATPtg.logevent_currentTarget 2932.3426356888376
# lsst.sal.ATPtg.logevent_detailedState 4293.330697306271
# lsst.sal.ATPtg.logevent_elLimitWarning 37.194972308476764
# lsst.sal.ATPtg.logevent_errorCode 4622.570846126545
# lsst.sal.ATPtg.logevent_focusNameInconsistentWarning 61835.97975195447
# lsst.sal.ATPtg.logevent_focusNameSelected 37.01820587783024
# lsst.sal.ATPtg.logevent_moonProximityWarning 53007.54904283796
# lsst.sal.ATPtg.logevent_mountDataWarning 38.22990130264823
# lsst.sal.ATPtg.logevent_objectSetWarning 61835.95309571425
# lsst.sal.ATPtg.logevent_pointingModel 37.01911172659501
# lsst.sal.ATPtg.logevent_ptgAzCurrentWrap 37.017573938650244
# lsst.sal.ATPtg.logevent_ptgRotCurrentWrap 37.017625274377714
# lsst.sal.ATPtg.logevent_rotWrapWarning 37.15028619766235
# lsst.sal.ATPtg.logevent_summaryState 37.015979881437126
# lsst.sal.ATPtg.logevent_sunProximityWarning 37.13201509912809
# lsst.sal.ATPtg.logevent_trackPosting 37.012557144518254
# lsst.sal.ATPtg.logevent_wavelength 37.01745328201967
# lsst.sal.ATPtg.logevent_weatherDataApplied 37.165065740654526
# lsst.sal.ATPtg.logevent_weatherDataInvalid 37.13331156117575
# lsst.sal.ATPtg.mountStatus 37.007638485550196
# lsst.sal.ATPtg.timeAndDate 37.00467262838376
# lsst.sal.Environment.ackcmd 134.56837879112382
# lsst.sal.Environment.airPressure 37.00067714622531
# lsst.sal.Environment.airTemperature 37.000554539023376
# lsst.sal.Environment.command_disable 0.0014904439449310303
# lsst.sal.Environment.command_enable 0.10498040372675116
# lsst.sal.Environment.command_enterControl 0.0007839202880859375
# lsst.sal.Environment.command_exitControl 0.0008105436960856119
# lsst.sal.Environment.command_standby 0.0006343788570827908
# lsst.sal.Environment.command_start 0.0006085485219955444
# lsst.sal.Environment.dewPoint 37.00068462762742
# lsst.sal.Environment.logevent_errorCode 6006.03306731811
# lsst.sal.Environment.logevent_heartbeat 37.011064101044624
# lsst.sal.Environment.logevent_logLevel 1706.9376167761973
# lsst.sal.Environment.logevent_logMessage 37.00072937147279
# lsst.sal.Environment.logevent_settingVersions 1706.9374233270303
# lsst.sal.Environment.logevent_simulationMode 1706.9369125305077
# lsst.sal.Environment.logevent_summaryState 479.9145749701935
# lsst.sal.Environment.precipitation 37.00067583343622
# lsst.sal.Environment.relativeHumidity 37.026820235756695
# lsst.sal.Environment.snowDepth 37.00068291249012
# lsst.sal.Environment.soilTemperature 37.000693489518014
# lsst.sal.Environment.solarNetRadiation 37.0006746160953
# lsst.sal.Environment.weather 37.00066277399531
# lsst.sal.Environment.windDirection 37.000693377450155
# lsst.sal.Environment.windGustDirection 37.00064742195375
# lsst.sal.Environment.windSpeed 37.00068158836529
# lsst.sal.GenericCamera.ackcmd 242773716.90659773
# lsst.sal.GenericCamera.command_disable 0.0007275581359863281
# lsst.sal.GenericCamera.command_enable 0.0005528756550380162
# lsst.sal.GenericCamera.command_exitControl 0.000693504626934345
# lsst.sal.GenericCamera.command_standby 0.0006030678749084472
# lsst.sal.GenericCamera.command_start 0.0006298010165874774
# lsst.sal.GenericCamera.command_startLiveView 0.0006549493321832621
# lsst.sal.GenericCamera.command_stopLiveView 0.0014577176835801867
# lsst.sal.GenericCamera.command_takeImages 0.00059721140357537
# lsst.sal.GenericCamera.logevent_appliedSettingsMatchStart 242772284.02462137
# lsst.sal.GenericCamera.logevent_endReadout 242603452.50207508
# lsst.sal.GenericCamera.logevent_errorCode 242892637.74697638
# lsst.sal.GenericCamera.logevent_heartbeat 242678705.3936748
# lsst.sal.GenericCamera.logevent_logLevel 242800584.25994942
# lsst.sal.GenericCamera.logevent_logMessage 243000985.105765
# lsst.sal.GenericCamera.logevent_settingVersions 242811523.83506134
# lsst.sal.GenericCamera.logevent_simulationMode 242800584.2597006
# lsst.sal.GenericCamera.logevent_startIntegration 242605434.1934974
# lsst.sal.GenericCamera.logevent_startLiveView 242856723.1576552
# lsst.sal.GenericCamera.logevent_startReadout 242605434.1944175
# lsst.sal.GenericCamera.logevent_summaryState 242809632.24062458
