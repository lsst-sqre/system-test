# %% [markdown]
# # LSST SODA Service Tutorial
#
# This notebook introduces the LSST Server-side Operations for Data Access (SODA) web service. SODA is an IVOA Recommendation for data access, described in detail at http://www.ivoa.net/documents/SODA/20170517/REC-SODA-1.0.html.
#
# In the context of the LSST Science Platform, SODA service is intended to support retrieval of manipulated image files (e.g. image cutouts and/or stitches) and to mediate retrieval of "virtual" data products that may need to be regenerated by the platform back-end on demand.
#
# ### Notebook Usage
#
# This notebook assumes it is being executed in the notebook aspect of the Rubin Science Platform somewhere with access to a SODA service that can provide the appropriate products (in this case `default.calexp.r`), such as the data facility at NCSA (https://lsst-lsp-stable.ncsa.illinois.edu/nb).
#
# In the following steps, we will create and dispatch several requests for manipulated images based on these products.  The retrived images will be displayed inline in the notebook.
#
# For request dispatch we will be using `pyvo`: https://pyvo.readthedocs.io/en/latest/index.html.  For image display, we will be using the `lsst.afw.display` library.
#
# ## 1. Import and Setup Support Libraries
#
# The following cell brings in pyvo, matplotlib, and the LSST afw display and image libraries.  `afwDisplay` is then configured to display via `matplotlib`.  Finally we define the URL and ID we will use for our queries:

# %%
import os
import pyvo

import matplotlib.pyplot as plt

import lsst.afw.display as afwDisplay
import lsst.afw.image as afwImage

afwDisplay.setDefaultBackend('matplotlib')

host=os.getenv("EXTERNAL_INSTANCE_URL" or "https://lsst-lsp-stable.ncsa.illinois.edu")
SODA_URL="{}/api/image/soda/sync".format(host)
ID='default.calexp.r'
print(SODA_URL)
# Out:
# https://data-int.lsst.cloud/api/image/soda/sync

# %% [markdown]
# ## 2. Retrieve a Circular Cutout
#
# Here we use a `pyvo` helper to construct a query for a circular cutout, execute the query and stream the results (a FITS file) to the user's workspace, then display the file inline using `afw.display`:

# %%
size = 20/3600 # 20 arcseconds
q1 = pyvo.dal.adhoc.SodaQuery(
    SODA_URL, 
    ID=ID, 
    POS='CIRCLE 216.68 -0.53 %03.3f' % size
)

sodaCircle = os.path.join(os.getenv('HOME'), 'DATA/soda-circle.fits')
with open(sodaCircle, 'bw+') as f1:
    f1.write(q1.execute_stream().read())
    
i1 = afwImage.ImageF(sodaCircle)        #read FITS file into afw image object
plt.figure()                            #create a matplotlib.pyplot figure
afw_display = afwDisplay.Display()      #get an alias to the lsst.afw.display.Display() method
afw_display.scale('asinh', 'zscale')    #set the image stretch algorithm and range
afw_display.mtv(i1)                     #load the image into the display
plt.show()                              #show the corresponding pyplot figure
# Out:
# ---------------------------------------------------------------------------
# FitsError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 12>()
#       9 with open(sodaCircle, 'bw+') as f1:
#      10     f1.write(q1.execute_stream().read())
# ---> 12 i1 = afwImage.ImageF(sodaCircle)        #read FITS file into afw image object
#      13 plt.figure()                            #create a matplotlib.pyplot figure
#      14 afw_display = afwDisplay.Display()      #get an alias to the lsst.afw.display.Display() method
#
# FitsError:
#   File "src/fits.cc", line 1585, in lsst::afw::fits::Fits::Fits(const string&, const string&, int)
#     cfitsio error: 1st key not SIMPLE or XTENSION (252) : Opening file '/home/cbanek/DATA/soda-circle.fits' with mode 'r'
# cfitsio error stack:
#   Extension doesn't start with SIMPLE or XTENSION keyword. (ffrhdu)
#   <!DOCTYPE html><html lang="en" dir="ltr"><head><meta name="viewport" content="wi
#   ffopen could not interpret primary array header of file:
#   /home/cbanek/DATA/soda-circle.fits
#   This does not look like a FITS file.
#  {0}
# lsst::afw::fits::FitsError: 'cfitsio error: 1st key not SIMPLE or XTENSION (252) : Opening file '/home/cbanek/DATA/soda-circle.fits' with mode 'r'
# cfitsio error stack:
#   Extension doesn't start with SIMPLE or XTENSION keyword. (ffrhdu)
#   <!DOCTYPE html><html lang="en" dir="ltr"><head><meta name="viewport" content="wi
#   ffopen could not interpret primary array header of file:
#   /home/cbanek/DATA/soda-circle.fits
#   This does not look like a FITS file.
# '

# %% [markdown]
# ## 3. Retrieve a Lon/Lat Range Cutout
#
# As above, but for a lon/lat range:

# %%
q2 = pyvo.dal.adhoc.SodaQuery(
    SODA_URL, 
    ID=ID, 
    POS='RANGE 216.67 216.69 -0.525 -0.535'
)

sodaRange = os.path.join(os.getenv('HOME'), 'DATA/soda-range.fits')
with open(sodaRange, 'bw+') as f2:
    f2.write(q2.execute_stream().read())
    
i2 = afwImage.ImageF(sodaRange)         #read FITS file into afw image object
plt.figure()                            #create a matplotlib.pyplot figure
afw_display = afwDisplay.Display()      #get an alias to the lsst.afw.display.Display() method
afw_display.scale('asinh', 'zscale')    #set the image stretch algorithm and range
afw_display.mtv(i2)                     #load the image into the display
plt.show()                              #show the corresponding pyplot figure
# Out:
# ---------------------------------------------------------------------------
# FitsError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 11>()
#       8 with open(sodaRange, 'bw+') as f2:
#       9     f2.write(q2.execute_stream().read())
# ---> 11 i2 = afwImage.ImageF(sodaRange)         #read FITS file into afw image object
#      12 plt.figure()                            #create a matplotlib.pyplot figure
#      13 afw_display = afwDisplay.Display()      #get an alias to the lsst.afw.display.Display() method
#
# FitsError:
#   File "src/fits.cc", line 1585, in lsst::afw::fits::Fits::Fits(const string&, const string&, int)
#     cfitsio error: 1st key not SIMPLE or XTENSION (252) : Opening file '/home/cbanek/DATA/soda-range.fits' with mode 'r'
# cfitsio error stack:
#   Extension doesn't start with SIMPLE or XTENSION keyword. (ffrhdu)
#   <!DOCTYPE html><html lang="en" dir="ltr"><head><meta name="viewport" content="wi
#   ffopen could not interpret primary array header of file:
#   /home/cbanek/DATA/soda-range.fits
#   This does not look like a FITS file.
#  {0}
# lsst::afw::fits::FitsError: 'cfitsio error: 1st key not SIMPLE or XTENSION (252) : Opening file '/home/cbanek/DATA/soda-range.fits' with mode 'r'
# cfitsio error stack:
#   Extension doesn't start with SIMPLE or XTENSION keyword. (ffrhdu)
#   <!DOCTYPE html><html lang="en" dir="ltr"><head><meta name="viewport" content="wi
#   ffopen could not interpret primary array header of file:
#   /home/cbanek/DATA/soda-range.fits
#   This does not look like a FITS file.
# '

# %% [markdown]
# ## Retrieve a Polygonal Cutout
#
# As above, but for a polygonal region:

# %%
q3 = pyvo.dal.adhoc.SodaQuery(
    SODA_URL, 
    ID=ID, 
    POS='POLYGON 216.67 -0.52 216.685 -0.52 216.677 -0.54'
)

sodaPoly = os.path.join(os.getenv('HOME'), 'DATA/soda-polygon.fits')
with open(sodaPoly, 'bw+') as f3:
    f3.write(q3.execute_stream().read())
    
i3 = afwImage.ImageF(sodaPoly)          #read FITS file into afw image object
plt.figure()                            #create a matplotlib.pyplot figure
afw_display = afwDisplay.Display()      #get an alias to the lsst.afw.display.Display() method
afw_display.scale('asinh', 'zscale')    #set the image stretch algorithm and range
afw_display.mtv(i3)                     #load the image into the display
plt.show()                              #show the corresponding pyplot figure
